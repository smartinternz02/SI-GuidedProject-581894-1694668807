# %% [markdown]
# DATA VISUALIATION:

# %%
import matplotlib.pyplot as pt

# %%
import numpy as np
import pandas as pd

# %%
import seaborn as sb

# %%
print(sb.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
d=sb.load_dataset('car_crashes')
d
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   total           51 non-null     float64
#  1   speeding        51 non-null     float64
#  2   alcohol         51 non-null     float64
#  3   not_distracted  51 non-null     float64
#  4   no_previous     51 non-null     float64
#  5   ins_premium     51 non-null     float64
#  6   ins_losses      51 non-null     float64
#  7   abbrev          51 non-null     object
# dtypes: float64(7), object(1)
# memory usage: 3.3+ KB

# %%
d.head(5)
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %%
sb.scatterplot(x="speeding",y="alcohol",data=d)
# Out:
# <Axes: xlabel='speeding', ylabel='alcohol'>

# %%
sb.scatterplot(x="abbrev",y="total",data=d)
# Out:
# <Axes: xlabel='abbrev', ylabel='total'>

# %%
sb.lineplot(x="ins_losses",y="not_distracted",data=d)
# Out:
# <Axes: xlabel='ins_losses', ylabel='not_distracted'>

# %%
sb.lineplot(x="no_previous",y="ins_premium",data=d,ci=None)
# Out:
# <ipython-input-14-4cfbc3f4d0ba>:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sb.lineplot(x="no_previous",y="ins_premium",data=d,ci=None)
# <Axes: xlabel='no_previous', ylabel='ins_premium'>

# %%
sb.distplot(d["speeding"])
# Out:
# <ipython-input-20-159c16c9cdd5>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(d["speeding"])
# <Axes: xlabel='speeding', ylabel='Density'>

# %%
sb.distplot(d["total"])
# Out:
# <ipython-input-22-bb99e33558ec>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(d["total"])
# <Axes: xlabel='total', ylabel='Density'>

# %%
sb.relplot(x="total",y="ins_losses",data=d,hue="abbrev")

# %%
sb.relplot(x="total",y="ins_losses",data=d,hue="speeding")

# %%
d["abbrev"].value_counts()
# Out:
# AL    1
# PA    1
# NV    1
# NH    1
# NJ    1
# NM    1
# NY    1
# NC    1
# ND    1
# OH    1
# OK    1
# OR    1
# RI    1
# MT    1
# SC    1
# SD    1
# TN    1
# TX    1
# UT    1
# VT    1
# VA    1
# WA    1
# WV    1
# WI    1
# NE    1
# MO    1
# AK    1
# ID    1
# AZ    1
# AR    1
# CA    1
# CO    1
# CT    1
# DE    1
# DC    1
# FL    1
# GA    1
# HI    1
# IL    1
# MS    1
# IN    1
# IA    1
# KS    1
# KY    1
# LA    1
# ME    1
# MD    1
# MA    1
# MI    1
# MN    1
# WY    1
# Name: abbrev, dtype: int64

# %%
d["total"].value_counts()
# Out:
# 14.1    2
# 12.8    2
# 13.6    2
# 21.4    2
# 19.4    2
# 23.9    2
# 14.9    1
# 14.7    1
# 11.6    1
# 11.2    1
# 18.4    1
# 12.3    1
# 16.8    1
# 19.9    1
# 17.6    1
# 18.2    1
# 11.1    1
# 19.5    1
# 11.3    1
# 12.7    1
# 10.6    1
# 23.8    1
# 13.8    1
# 16.1    1
# 18.8    1
# 9.6     1
# 18.1    1
# 18.6    1
# 22.4    1
# 12.0    1
# 10.8    1
# 16.2    1
# 5.9     1
# 17.9    1
# 15.6    1
# 17.5    1
# 15.3    1
# 14.5    1
# 15.7    1
# 17.8    1
# 20.5    1
# 15.1    1
# 12.5    1
# 8.2     1
# 17.4    1
# Name: total, dtype: int64

# %%
sb.barplot(data=d,x="alcohol",y="not_distracted",ci=None)
# Out:
# <ipython-input-31-562dbfa0d0cd>:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sb.barplot(data=d,x="alcohol",y="not_distracted",ci=None)
# <Axes: xlabel='alcohol', ylabel='not_distracted'>

# %%
sb.barplot(data=d,x="speeding",y="total",ci=None)
# Out:
# <ipython-input-33-91a42b139e20>:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sb.barplot(data=d,x="speeding",y="total",ci=None)
# <Axes: xlabel='speeding', ylabel='total'>

# %%
sb.countplot(x="total",data=d)
# Out:
# <Axes: xlabel='total', ylabel='count'>

# %%
sb.jointplot(x="total",y="ins_losses",data=d)

# %%
sb.boxplot(x="speeding",y="total",data=d)
# Out:
# <Axes: xlabel='speeding', ylabel='total'>

# %%
c=d.corr()
c
# Out:
# <ipython-input-42-5f19c76252da>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   c=d.corr()
#                    total  speeding   alcohol  not_distracted  no_previous  \
# total           1.000000  0.611548  0.852613        0.827560     0.956179
# speeding        0.611548  1.000000  0.669719        0.588010     0.571976
# alcohol         0.852613  0.669719  1.000000        0.732816     0.783520
# not_distracted  0.827560  0.588010  0.732816        1.000000     0.747307
# no_previous     0.956179  0.571976  0.783520        0.747307     1.000000
# ins_premium    -0.199702 -0.077675 -0.170612       -0.174856    -0.156895
# ins_losses     -0.036011 -0.065928 -0.112547       -0.075970    -0.006359
#
#                 ins_premium  ins_losses
# total             -0.199702   -0.036011
# ...

# %%
sb.heatmap(c,annot=True)
# Out:
# <Axes: >

# %%
d.shape
# Out:
# (51, 8)

# %%
pt.subplots(figsize=(20,25))
sb.heatmap(c,annot=True)
# Out:
# <Axes: >

# %%
d.total.value_counts()
# Out:
# 14.1    2
# 12.8    2
# 13.6    2
# 21.4    2
# 19.4    2
# 23.9    2
# 14.9    1
# 14.7    1
# 11.6    1
# 11.2    1
# 18.4    1
# 12.3    1
# 16.8    1
# 19.9    1
# 17.6    1
# 18.2    1
# 11.1    1
# 19.5    1
# 11.3    1
# 12.7    1
# 10.6    1
# 23.8    1
# 13.8    1
# 16.1    1
# 18.8    1
# 9.6     1
# 18.1    1
# 18.6    1
# 22.4    1
# 12.0    1
# 10.8    1
# 16.2    1
# 5.9     1
# 17.9    1
# 15.6    1
# 17.5    1
# 15.3    1
# 14.5    1
# 15.7    1
# 17.8    1
# 20.5    1
# 15.1    1
# 12.5    1
# 8.2     1
# 17.4    1
# Name: total, dtype: int64

# %%
d.isnull().any()
# Out:
# total             False
# speeding          False
# alcohol           False
# not_distracted    False
# no_previous       False
# ins_premium       False
# ins_losses        False
# abbrev            False
# dtype: bool

# %%
d.head()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %% [markdown]
# THE END.
